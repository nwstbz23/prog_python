# %%
#programming code is correct but need to fix 199.
# score is fixed at 199. So the only variable that is changed is the name.
score = 199
name = input("enter your name:")
print(name, "your score is", score)
# Out:
# enter your name:199
# 199 your score is 199

# %%
# To add "def add_score(current): return current + 10" into line 1 

name = "Tamara" 
def add_score(current): 
    return current + 10 
score = add_score(190)    
print(name, "your score is", score)
# Out:
# Tamara your score is 200

# %%
# to remove line(s) so that the codes can run

#original code
greet(name) --> to remove
name = input("enter your name: ") 
greet(name) --> to remove
def greet(person):
    print("Hi,", person)
greet(name)

#revised code after removing line 1 and 3
name = input("enter your name: ")
def greet(person):
    print("Hi,", person)
greet(name)

# %%
#establish code to convert text to lower case
def low_case(words_in): return words_in.lower()
words_lower = low_case("Return THIS lower")
print(words_lower)
# Out:
# return this lower

# %%
#to obtain syntax error
PriNt("Hello World!")

# %%
# Create Allergy check code for Module 1 lab assignment
# [ ] get input for input_test variable
greeting = "hello"
food_eaten = input ("What kind of food have you been eaten in the past 24 hours? ")
print (greeting, food_eaten.lower())
# [ ] print "True" message if "dairy" is in the input or False message if not
print ("It is" ,"dairy" in food_eaten.lower(), "that in your eaten food: ","there is dairy")
# [ ] print True message if "nuts" is in the input or False if not
print ("It is" ,"nuts" in food_eaten.lower(), "that in your eaten food:","there is nuts")
# [ ] Challenge: Check if "seafood" is in the input - print message
print ("It is" ,"seafood" in food_eaten.lower(), "that in your eaten food:","there is seafood")
# [ ] Challenge: Check if "chocolate" is in the input - print message
print ("It is" ,"chocolate" in food_eaten.lower(), "that in your eaten food:","there is chocolate")
# Out:
# What kind of food have you been eaten in the past 24 hours? SEAfooD
# hello seafood
# It is False that in your eaten food:  there is dairy
# It is False that in your eaten food: there is nuts
# It is True that in your eaten food: there is seafood
# It is False that in your eaten food: there is chocolate

# %%
print (3+5)
print ("a")

a = "Welcome"
print(a)
b = "to Python"
print(b)
print(a,b)
print(a+b)
print(a,b,"Programming")
print(a,b,"Programming",236)
print(a+b+"Programming"+236)
# Out:
# 8
# a
# Welcome
# to Python
# Welcome to Python
# Welcometo Python
# Welcome to Python Programming
# Welcome to Python Programming 236
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-3054e4362f17> in <module>
#      10 print(a,b,"Programming")
#      11 print(a,b,"Programming",236)
# ---> 12 print(a+b+"Programming"+236)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = input("PLease input any number ")
b = input("PLease input any number ")

c=int(a) + int(b)
print(c)
type (c)
# Out:
# PLease input any number 30
# PLease input any number 21
# 51
# int

# %%
a = input("Please input any number ")
type(a)
# because a is a string defined variable.
# Out:
# Please input any number 1
# str

# %%
print("\\\\\\\\")
print("Hello\nWorld!")
# no indentation for first code
print("It's" + "Python Time!") 
print("It's\nPython Time!")
print("It's" + "\nPython Time!")
print("It\'s\nPython Time!")
# Out:
# \\\\
# Hello
# World!
# It'sPython Time!
# It's
# Python Time!
# It's
# Python Time!
# It's
# Python Time!

# %%
num_1 = ""
num_temp = ""
num_final = ""

while True:
    num_1 = input("Enter an integer: ")
    if num_1.isdigit():
        num_final = num_temp + num_1
        num_temp = num_final
    else:
        print(num_final)
        break
# Out:
# Enter an integer: 0
# Enter an integer: 0
# Enter an integer: two
# 00

# %%
x = 0 

while True:
    if x < 10:
        print('run forever')
        x += 1
    else:
        break
# Out:
# run forever
# run forever
# run forever
# run forever
# run forever
# run forever
# run forever
# run forever
# run forever
# run forever

# %%
time = 3

while True:
    print('time is', time)
    if time == 3:
        time = 4
    else:
        break
# Out:
# time is 3
# time is 4

# %%
x = 0 

while x < 5:
    x += 1
    print('loop')
# Out:
# loop
# loop
# loop
# loop
# loop

# %%
def ignore_case(name):
    answer = ""
    while answer.isalpha() == False:
        answer = input("enter last name: ")
    return answer.lower() == name.lower()
